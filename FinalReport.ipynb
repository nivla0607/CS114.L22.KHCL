# %% [markdown]
# <a href="https://colab.research.google.com/github/nivla0607/CS114.L22.KHCL/blob/main/FinalReport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<h1 align="center"><b>ĐỒ ÁN CUỐI KỲ </b></h1>
# <h2 align="center"><b></b></h2>
# <h2 align="center"><b>TÊN ĐỒ ÁN: NHẬN DIỆN CÁC LOẠI BIỂN BÁO GIAO THÔNG</b></h1>

# %% [markdown]
# # 1.GIỚI THIỆU

# %% [markdown]
# Giảng viên hướng dẫn:
# *   Lê Đình Duy
# *   Phạm Nguyễn Trường An

# %% [markdown]
# Sinh viên thực hiện:
# *   Nguyễn Phạm Vĩnh Nguyên - 19520186
# *   Phạm Minh Khôi - 19520658
# *   Phạm Quốc Đạt - 19521349

# %% [markdown]
# # 2.MÔ TẢ BÀI TOÁN

# %% [markdown]
# Vào thời đại khoa học kỹ thuật bùng nổ như hiện, chúng ta đang phải đối mặt với cách mạng công nghiệp 4.0, vậy nên xe tự hành không phải là một định nghĩa quá xa lạ với chúng ta. Nhưng trên thực tế dù đã có các ý tưởng về xe tự hành từ khá sớm nhưng vẫn chưa có nhiều công ty trên thế giới đã thực sự phát triển và kinh doanh được loại phương tiện giao thông này. Các vấn đề chính phải gặp khi phát triển xe tự hành thường là các vấn đề liên quan đến an toàn của người sử dụng và trong đó không thể không nhắc đến vấn đề về khả năng nhận diện hình ảnh của xe tự hành, cụ thể hơn trong bài toán này chính là nhận diện các loại biển báo giao thông. Với ngay cả con người chúng ta việc nhận diện và nhớ hết tất cả biển báo giao thông cũng không phải là việc đơn giản, điều đó càng cho thấy tầm quan trọng của việc nhận diện các biển báo và đó cũng là vấn đề mà chúng em sẽ giải quyết trong bài toán này.

# %% [markdown]
# *   Input: Một file hình ảnh có kích thước bất kỳ
# *   Output: Tấm hình input với biển báo giao thông được khoanh vùng (nếu có) và tên loại biển báo ấy

# %% [markdown]
# # 3.MÔ TẢ VỀ BỘ DỮ LIỆU

# %% [markdown]
# ![f8a92a53-20190806_040411.gif](data:image/gif;base64,...)

# %% [markdown]
# *   Nhóm chúng em sẽ thu thập cỡ 3000 ngàn tấm hình về các loại biển báo giao thông trên các đoạn đường tại TP.HCM, tập trung chủ yếu vào các loại biển báo cấm trên.
#
# *   Hình thức thu thập dữ liệu là nhóm chúng em sẽ trực tiếp đi xung quanh các khu vực TP.HCM để chụp lại các tấm hình có chứa biển báo giao thông ở những góc độ và những môi trường chân thật nhất để quá trình train có thể đưa ra kết quả thực tế và chuẩn xác nhất
#
# *   Dưới đây là một số hình ảnh demo về bộ dữ liệu mà chúng em sẽ thu thập

# %% [markdown]
# ![196738777_967410107427697_5493837340345205369_n.jpg](data:image/jpeg;base64,...)![195959784_1129186934249426_3174097366122556245_n.jpg](data:image/jpeg;base64,...)![195617039_1494433314232454_9107717553282212108_n.jpg](data:image/jpeg;base64,...)![195407168_221035962983685_429496292686717442_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# *   Chúng em sẽ chia bộ dữ liệu thành tập train và tập test theo tỉ lệ 90:10
# *   Chúng em sẽ sử dụng thư viện OpenCV để vẽ các bouding box và gán nhãn cho từng hình
